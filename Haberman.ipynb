# %% [markdown]
# <a href="https://colab.research.google.com/github/DzikriEl/Haberman-Dataset/blob/main/Haberman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Menambahkan Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Untuk membaca data berektensi csv kita menggunakan library pandas dan menggunakan perintah read.csv

# %%
from pandas import read_csv

# %% [markdown]
# Dataset Haberman, File Path untuk menampung Dataset Haberman, sedangkan Untuk atributes menampilkan kolom atau isi yang ada pada dataset Haberman

# %%
file_path = r'https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data'
attributes = ['Age of patient at time of operation', 'Patients year of operation', 'Number of positive axillary nodes detected','class']
dataset = pd.read_csv(file_path, names=attributes)

# %% [markdown]
# Menampilkan Data Set Haberman

# %%
dataset
# Out:
#      Age of patient at time of operation  ...  class
# 0                                     30  ...      1
# 1                                     30  ...      1
# 2                                     30  ...      1
# 3                                     31  ...      1
# 4                                     31  ...      1
# ..                                   ...  ...    ...
# 301                                   75  ...      1
# 302                                   76  ...      1
# 303                                   77  ...      1
# 304                                   78  ...      2
# 305                                   83  ...      2
#
# [306 rows x 4 columns]

# %% [markdown]
# Menampilkan Data Teratas

# %%
print(dataset.head())
# Out:
#    Age of patient at time of operation  ...  class
# 0                                   30  ...      1
# 1                                   30  ...      1
# 2                                   30  ...      1
# 3                                   31  ...      1
# 4                                   31  ...      1
#
# [5 rows x 4 columns]

# %%
print(dataset.head(10))
# Out:
#    Age of patient at time of operation  ...  class
# 0                                   30  ...      1
# 1                                   30  ...      1
# 2                                   30  ...      1
# 3                                   31  ...      1
# 4                                   31  ...      1
# 5                                   33  ...      1
# 6                                   33  ...      1
# 7                                   34  ...      2
# 8                                   34  ...      2
# 9                                   34  ...      1
#
# [10 rows x 4 columns]

# %% [markdown]
# Menampilkan Data Terbawah

# %%
print(dataset.tail(10))
# Out:
#      Age of patient at time of operation  ...  class
# 296                                   72  ...      1
# 297                                   73  ...      1
# 298                                   73  ...      1
# 299                                   74  ...      2
# 300                                   74  ...      1
# 301                                   75  ...      1
# 302                                   76  ...      1
# 303                                   77  ...      1
# 304                                   78  ...      2
# 305                                   83  ...      2
#
# [10 rows x 4 columns]

# %% [markdown]
# Menampilkan Kolom yang ada pada dataset

# %%
print(dataset.keys())
# Out:
# Index(['Age of patient at time of operation', 'Patients year of operation',
#        'Number of positive axillary nodes detected', 'class'],
#       dtype='object')

# %% [markdown]
# Jumlah Kolom dan Baris

# %%
print(dataset.shape)
# Out:
# (306, 4)

# %% [markdown]
# Informasi dataset

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age of patient at time of operation         306 non-null    int64
#  1   Patients year of operation                  306 non-null    int64
#  2   Number of positive axillary nodes detected  306 non-null    int64
#  3   class                                       306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB
# None

# %% [markdown]
# Statistik Deskripsi

# %%
dataset.describe()
# Out:
#        Age of patient at time of operation  ...       class
# count                           306.000000  ...  306.000000
# mean                             52.457516  ...    1.264706
# std                              10.803452  ...    0.441899
# min                              30.000000  ...    1.000000
# 25%                              44.000000  ...    1.000000
# 50%                              52.000000  ...    1.000000
# 75%                              60.750000  ...    2.000000
# max                              83.000000  ...    2.000000
#
# [8 rows x 4 columns]

# %% [markdown]
# Visualisasi dengan Matplotlib untuk menampilkan Histogram Grafik

# %%
print(dataset.plot.hist(bins=15))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Visualisasi dengan Matplotlib - Scatter

# %%
dataset.plot(kind="scatter", x=["Age of patient at time of operation"], y=["Number of positive axillary nodes detected"], colorbar=True)

# %%
dataset.plot(kind ="scatter", x ='Age of patient at time of operation', y ='Number of positive axillary nodes detected')

# %% [markdown]
# *Visualisasi dengan Seaborn* Mengimport librarynya

# %%
import seaborn as sns

# %%
sns.FacetGrid(dataset, hue='class', height = 6).map(plt.scatter, 'Age of patient at time of operation','Number of positive axillary nodes detected').add_legend()

# %% [markdown]
# **TRAINING SET & DATA TESTING**

# %%
from sklearn.model_selection import train_test_split

# %%
x = dataset[['Age of patient at time of operation', 'Patients year of operation', 'Number of positive axillary nodes detected']]
y = dataset[['class']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
len(x_test)
x_test
# Out:
#      Age of patient at time of operation  ...  Number of positive axillary nodes detected
# 204                                   57  ...                                           0
# 58                                    42  ...                                           4
# 26                                    38  ...                                           0
# 10                                    34  ...                                           1
# 85                                    45  ...                                          14
# ..                                   ...  ...                                         ...
# 214                                   58  ...                                           2
# 128                                   50  ...                                           0
# 40                                    40  ...                                           2
# ...

# %% [markdown]
# **Classification Haberman using Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split

# %%
data_column = dataset[['Age of patient at time of operation', 'Patients year of operation', 'Number of positive axillary nodes detected']].values

data_class = dataset[['class']].values

# %%
(train_inputs, test_inputs, train_classes, test_classes) = train_test_split(data_column, data_class, train_size=0.7, random_state=1)

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(train_inputs, train_classes)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# **KEAKURATAN**

# %%
dtc.score(test_inputs, test_classes)
# Out:
# 0.6413043478260869

# %%
y_pred = dtc.predict(test_inputs)

# %%
from sklearn.metrics import classification_report
print(classification_report(test_classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.69      0.74        70
#            2       0.33      0.50      0.40        22
#
#     accuracy                           0.64        92
#    macro avg       0.57      0.59      0.57        92
# weighted avg       0.70      0.64      0.66        92

# %% [markdown]
# **Visual Classification**

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
dot_data = StringIO()

# %%
export_graphviz(dtc, out_file=dot_data, filled=True, rounded=True, special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph.create_png())
